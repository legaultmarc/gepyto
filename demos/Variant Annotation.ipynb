# %% [markdown]
# We will describe how to find a list of SNPs from a gene transcript and annotate by querying external databases and tools. This is meant to demonstrate the useful abstraction that ``gepyto`` provides to bioinformaticists.

# %%
import pprint

import gepyto
import gepyto.utils as utils
from gepyto.structures.genes import Gene

# We use pprint to display things nicely.
pp = pprint.PrettyPrinter(indent=4)

# %%
# Build a gene object from a symbol.
g = Gene.factory_symbol("CKM")
print "Initialized the CKM gene from public databases: ", g
print "  Transcripts: ", g.transcripts
print "  Other Ids: "
pp.pprint(g.xrefs)
# Out:
# Initialized the CKM gene from public databases:  <Gene:CKM (chr19:45809672-45826235)>
#   Transcripts:  [<Transcript:ENST00000221476 (chr19:45809672-45826235)>]
#   Other Ids:
# {   'cosmic_id': u'CKM',
#     'ensembl_id': u'ENSG00000104879',
#     'name': u'creatine kinase, muscle',
#     'ncbi_id': u'1158',
#     'omim_ids': [123310],
#     'refseq_ids': [u'NM_001824'],
#     'ucsc_id': u'uc002pbd.4',
#     'uniprot_ids': [u'P06732']}

# %% [markdown]
# We successfully created a ``Gene`` object by simply using the known HGNC gene symbol. This fetched information about cross-references in other databases, the position of exons and the different transcripts (in this case only one).
#
# We will take this transcript and find all overlapping small scale genetic variants. Then, we will annotate these variants.

# %%
region = "chr{}:{}-{}".format(g.chrom, g.start, g.end)
print "Getting variants in region {}".format(region)

variants = utils.variants.ensembl_variants_in_region(region)

# An example of variant object:
print "gepyto provides Variant objects: ", variants[0]

# Proceed with CADD annotation.
cadd_annos = gepyto.annotation.cadd.cadd_score(variants)

# Also get regulation information from RegulomeDB
# RegulomeDB queries need to be separated by newlines for lists 
# and the positions have to be 0-based.
regul_annos = gepyto.annotation.regulome.query_regulomedb(
    "\n".join([v.get_position(zero_based=True) for v in variants])
)
# Out:
# WARNING:root:RS: None has only one allele (ignored).
# Getting variants in region chr19:45809672-45826235
# gepyto provides Variant objects:
#  chr19:45809672_A/T

# %%
# Example of CADD annotation.
print "CADD annotations are tuples of (feature, variant, c_score and information).\n"
tr, var, c_score, info = cadd_annos[0]
print  ("CADD predicts that the variant {} will have a "
        "consequence ({}) on the feature {}.".format(
    var, info["consequence"], tr
))

print "The assigned C Score = {}".format(c_score)
print

tr, var, c_score, info = cadd_annos[15]
print ("Another example is the ({}) effect of the variant {} "
       "on {}".format(info["consequence"], var, tr))

print "The assigned C Score = {}".format(c_score)

print  ("\nA total of {} annotations are provided "
        "for this region.".format(len(cadd_annos)))

print "\nRegulomeDB annotations are dictionaries that look like this: "
pp.pprint(regul_annos[0])
# Out:
# CADD annotations are tuples of (feature, variant, c_score and information).
#
# CADD predicts that the variant chr19:45809672_A/T will have a consequence (REGULATORY) on the feature ENSR00000216992.
# The assigned C Score = 14.17
#
# Another example is the (NON_SYNONYMOUS) effect of the variant chr19:45810026_C/G on ENST00000221476
# The assigned C Score = 22.0
#
# A total of 420 annotations are provided for this region.
#
# RegulomeDB annotations are dictionaries that look like this:
# {   'chrom': u'19',
#     'hits': [   [u'Motifs', u'Footprinting', u'Huh75', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Gm18507', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Osteobl', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'H1hesc', u'Sp1'],
#                 [u'Motifs', u'PWM', u'', u'SP4'],
#                 [u'Motifs', u'PWM', u'', u'Klf7'],
#                 [u'Motifs', u'Footprinting', u'Helas3Ifna4h', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'K562', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'H9es', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Gm18507', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Nhek', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Mcf7', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'A549', u'Sp1'],
#                 [u'Motifs', u'PWM', u'', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Huvec', u'Sp1'],
#                 [u'Motifs', u'PWM', u'', u'Zfp740'],
#                 [u'Motifs', u'PWM', u'', u'Zbtb7b'],
#                 [u'Motifs', u'Footprinting', u'Huh7', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Hsmm', u'RREB1'],
#                 [u'Motifs', u'PWM', u'', u'SP8'],
#                 [u'Motifs', u'Footprinting', u'K562', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Hepg2', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Hmec', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Cll', u'RREB1'],
#                 [u'Motifs', u'PWM', u'', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Fibrop', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Helas3', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Huvec', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Nhek', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'8988t', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'H1hesc', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Gm19239', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Osteobl', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'H9es', u'RREB1'],
#                 [u'Motifs', u'Footprinting', u'Huh75', u'Sp1'],
#                 [u'Motifs', u'Footprinting', u'Lncap', u'RREB1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Progfib'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Nb4'],
#                 [u'Chromatin_Structure', u'Diffa14d', u'DNase-seq', u'H7es'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Ipsnihi7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Htr8'],
#                 [u'Chromatin_Structure', u'Znfb34a8', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmvecdneo'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Fibropag08395'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hpde6e6e7'],
#                 [   u'Chromatin_Structure',
#                     u'',
#                     u'DNase-seq',
#                     u'Monocd14ro1746'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hrpe'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Huvec'],
#                 [   u'Chromatin_Structure',
#                     u'Est10nm30m',
#                     u'DNase-seq',
#                     u'Ishikawa'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Cd20ro01794'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Ipsnihi11'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Heartoc'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hcf'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'UrotsaUt189'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Panisd'],
#                 [   u'Chromatin_Structure',
#                     u'',
#                     u'DNase-seq',
#                     u'Fibroblgm03348'],
#                 [   u'Chromatin_Structure',
#                     u'Est100nm1h',
#                     u'DNase-seq',
#                     u'Mcf7'],
#                 [u'Chromatin_Structure', u'Znf4c50c4', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Sknsh'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hcpe'],
#                 [   u'Chromatin_Structure',
#                     u'Hypoxlaccon',
#                     u'DNase-seq',
#                     u'Mcf7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Lncap'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Nt2d1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'K562G2mphase'],
#                 [   u'Chromatin_Structure',
#                     u'',
#                     u'DNase-seq',
#                     u'Cerebrumfrontaloc'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmvecdad'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hcfaa'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm12891'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmveclbl'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'8988t'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm19240'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hah'],
#                 [u'Chromatin_Structure', u'ra', u'DNase-seq', u'Sknsh'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hvmf'],
#                 [   u'Chromatin_Structure',
#                     u'',
#                     u'DNase-seq',
#                     u'Olfneurosphere'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Stellate'],
#                 [u'Chromatin_Structure', u'Ctcfshrna', u'DNase-seq', u'Mcf7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm10248'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmvecdlyneo'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Ipscwru1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Th2'],
#                 [u'Chromatin_Structure', u'Estctrl0h', u'DNase-seq', u'Mcf7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Medullod341'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm20000'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hct116'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'H7es'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hsmm'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Fibropag08396'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Monocd14'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmf'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hpaf'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Th2wb54553204'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Panislets'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm13976'],
#                 [u'Chromatin_Structure', u'Znfa41c6', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'Znff41b2', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'H1hesc'],
#                 [   u'Chromatin_Structure',
#                     u'Lenticon',
#                     u'DNase-seq',
#                     u'Fibroblgm03348'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Adultcd4th0'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Fibrobl'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmvecdblad'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Nhbera'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Th1wb33676984'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hipe'],
#                 [u'Chromatin_Structure', u'Diffa5d', u'DNase-seq', u'H7es'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hff'],
#                 [u'Chromatin_Structure', u'Diffa9d', u'DNase-seq', u'H7es'],
#                 [   u'Chromatin_Structure',
#                     u'Tam10030',
#                     u'DNase-seq',
#                     u'Ishikawa'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Adultcd4th1'],
#                 [u'Chromatin_Structure', u'Andro', u'DNase-seq', u'Lncap'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gcbcell'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Mel2183'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Cll'],
#                 [   u'Chromatin_Structure',
#                     u'Saha1u72hr',
#                     u'DNase-seq',
#                     u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hl60'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Ips'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Mcf7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Colo829'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Fibrop'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Cmk'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hepatocytes'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm10266'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Nhek'],
#                 [   u'Chromatin_Structure',
#                     u'',
#                     u'DNase-seq',
#                     u'Frontalcortexoc'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'T47d'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gliobla'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'A549'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Huh7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm12865'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Caco2'],
#                 [u'Chromatin_Structure', u'Sahactrl', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'Nabut', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Helas3'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm19238'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hsmmt'],
#                 [u'Chromatin_Structure', u'Ifna4h', u'DNase-seq', u'Helas3'],
#                 [u'Chromatin_Structure', u'Znfp5', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hek293t'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Urotsa'],
#                 [   u'Chromatin_Structure',
#                     u'Est10nm30m',
#                     u'DNase-seq',
#                     u'T47d'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Rwpe1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm19239'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Huh75'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmec'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Osteobl'],
#                 [u'Chromatin_Structure', u'', u'FAIRE', u'K562'],
#                 [   u'Chromatin_Structure',
#                     u'Est10nm30m',
#                     u'DNase-seq',
#                     u'Ecc1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Phte'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Naivebcell'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hcm'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'H9es'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hee'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm13977'],
#                 [u'Chromatin_Structure', u'Diff4d', u'DNase-seq', u'Lhcnm2'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Imr90'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hepg2'],
#                 [   u'Chromatin_Structure',
#                     u'Lentimyod',
#                     u'DNase-seq',
#                     u'Fibroblgm03348'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hmveclly'],
#                 [u'Chromatin_Structure', u'Hypoxlac', u'DNase-seq', u'Mcf7'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Lhcnm2'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hsmmfshd'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Fibropag20443'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Hsmmemb'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Th1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'K562G1phase'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Medullo'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Chorion'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Myometr'],
#                 [u'Chromatin_Structure', u'Znfg54a11', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'Dm002p1h', u'DNase-seq', u'Ecc1'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm12892'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Jurkat'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm18507'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm12878'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Psoasmuscleoc'],
#                 [u'Chromatin_Structure', u'Randshrna', u'DNase-seq', u'Mcf7'],
#                 [u'Chromatin_Structure', u'Znf2c10c5', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Gm06990'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Cd20ro01778'],
#                 [u'Chromatin_Structure', u'Znf4g7d3', u'DNase-seq', u'K562'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Be2c'],
#                 [u'Chromatin_Structure', u'', u'DNase-seq', u'Rpmi7951'],
#                 [   u'Protein_Binding',
#                     u'02pct',
#                     u'ChIP-seq',
#                     u'ECC-1',
#                     u'POLR2A'],
#                 [u'Protein_Binding', u'', u'ChIP-seq', u'K562', u'RCOR1'],
#                 [u'Protein_Binding', u'', u'ChIP-seq', u'K562', u'CBX3'],
#                 [u'Protein_Binding', u'', u'ChIP-seq', u'K562', u'GTF2B'],
#                 [   u'Protein_Binding',
#                     u'ifng6h',
#                     u'ChIP-seq',
#                     u'K562',
#                     u'IRF1'],
#                 [u'Protein_Binding', u'', u'ChIP-seq', u'K562', u'PHF8']],
#     'pos': 45811506,
#     'rs': u'rs17875626',
#     'score': u'2b'}

# %% [markdown]
# This brief example shows some of the features of ``gepyto``. This is a fairly new project and will probably grow a lot more, integrating more sources of annotation. Nonetheless, the features described here show how easy it is to fetch gene, transcript and variant information from public databases using this tool.
